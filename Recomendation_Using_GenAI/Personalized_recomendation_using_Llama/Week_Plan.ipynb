# %%
import pandas as pd

# %%
df = pd.read_json('ai_response.json')

# %%
df
# Out:
#           day  meal_type                                          meal_name  \
# 0      Monday  breakfast             Italian-Style Omelette with Vegetables
# 1      Monday      lunch       Grilled Chicken Panini with Tomato and Basil
# 2      Monday     dinner  Spaghetti Squash with Meatballs and Marinara S...
# 3     Tuesday  breakfast              Greek Yogurt with Berries and Granola
# 4     Tuesday      lunch          Turkey and Avocado Wrap with Mixed Greens
# 5     Tuesday     dinner                     Baked Cod with Lemon and Herbs
# 6   Wednesday  breakfast  Whole-Grain Pancakes with Fresh Fruits and Yogurt
# 7   Wednesday      lunch    Veggie and Bean Chili with Whole-Grain Crackers
# 8   Wednesday     dinner      Shrimp and Vegetable Stir-Fry with Brown Rice
# 9    Thursday  breakfast    Egg and Spinach Omelette with Whole-Grain Toast
# 10   Thursday      lunch          Chicken and Vegetable Skewers with Quinoa
# ...

# %%
# Convert the JSON data into a DataFrame
df.to_csv('llama_resp.csv', index=False)
